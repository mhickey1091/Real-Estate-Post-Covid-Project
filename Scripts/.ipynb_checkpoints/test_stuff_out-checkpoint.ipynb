# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', 1000)

# %%
population = pd.read_csv(r'C:\Users\FLRea\Documents\NSS\Capstone\Data\population_new.csv')

# %%
population.head()
# Out:
#         State         2020         2021         2022         2023         2024
# 0     Alabama   5,033,094    5,049,196    5,076,181    5,117,673    5,157,699
# 1      Alaska     733,017      734,420      734,442      736,510      740,133
# 2     Arizona   7,187,135    7,274,078    7,377,566    7,473,027    7,582,384
# 3    Arkansas   3,014,546    3,026,870    3,047,704    3,069,463    3,088,354
# 4  California  39,521,958   39,142,565   39,142,414   39,198,693   39,431,263

# %%
population = pd.melt(population, id_vars=['State'], var_name = 'year', value_name = 'population')
population
# Out:
#              State  year   population
# 0          Alabama  2020   5,033,094
# 1           Alaska  2020     733,017
# 2          Arizona  2020   7,187,135
# 3         Arkansas  2020   3,014,546
# 4       California  2020  39,521,958
# ..             ...   ...          ...
# 250       Virginia  2024   8,811,195
# 251     Washington  2024   7,958,180
# 252  West Virginia  2024   1,769,979
# 253      Wisconsin  2024   5,960,975
# 254        Wyoming  2024     587,618
#
# [255 rows x 3 columns]

# %%
realestate = pd.read_csv(r'C:\Users\FLRea\Documents\NSS\Capstone\Data\state_market_tracker.csv')

# %%
realestate.head()
# Out:
#   period_begin  period_end region_type  region_type_id  table_id is_seasonally_adjusted          region  city           state state_code              property_type  property_type_id  median_sale_price  median_sale_price_mom  median_sale_price_yoy  median_list_price  median_list_price_mom  median_list_price_yoy  median_ppsf  median_ppsf_mom  median_ppsf_yoy  median_list_ppsf  median_list_ppsf_mom  median_list_ppsf_yoy  homes_sold  homes_sold_mom  homes_sold_yoy  pending_sales  pending_sales_mom  pending_sales_yoy  new_listings  new_listings_mom  new_listings_yoy  inventory  inventory_mom  inventory_yoy  months_of_supply  months_of_supply_mom  months_of_supply_yoy  median_dom  median_dom_mom  median_dom_yoy  avg_sale_to_list  avg_sale_to_list_mom  avg_sale_to_list_yoy  sold_above_list  sold_above_list_mom  sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  off_market_in_two_weeks  off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy parent_metro_region  \
# ...

# %%
realestate.period_begin = pd.to_datetime(realestate.period_begin)

# %%
realestate.period_end = pd.to_datetime(realestate.period_end)
